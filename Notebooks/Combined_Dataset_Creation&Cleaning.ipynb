# %%
import pandas as pd 
customer_info=pd.read_csv('../Dataset/Customer_info.csv')
location=pd.read_csv('../Dataset/Location_Data.csv')
services=pd.read_csv('../Dataset/Online_Services.csv')
payment_info=pd.read_csv('../Dataset/Payment_Info.csv')
service_options=pd.read_csv('../Dataset/Service_Options.csv')
status=pd.read_csv('../Dataset/Status_Analysis.csv')

# %% [markdown]
# # CUSTOMER_INFO.CSV (Data is clean,no null values,no duplicates)

# %%
customer_info.head()
# Out:
#   customer_id  gender  age under_30 senior_citizen partner dependents  \
# 0  0002-ORFBO  Female   37       No             No     Yes         No
# 1  0003-MKNFE    Male   46       No             No      No         No
# 2  0004-TLHLJ    Male   50       No             No      No         No
# 3  0011-IGKFF    Male   78       No            Yes     Yes         No
# 4  0013-EXCHZ  Female   75       No            Yes     Yes         No
#
#    number_of_dependents married
# 0                     0     Yes
# 1                     0      No
# 2                     0      No
# 3                     0     Yes
# 4                     0     Yes

# %%
customer_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           7043 non-null   object
#  1   gender                7043 non-null   object
#  2   age                   7043 non-null   int64
#  3   under_30              7043 non-null   object
#  4   senior_citizen        7043 non-null   object
#  5   partner               7043 non-null   object
#  6   dependents            7043 non-null   object
#  7   number_of_dependents  7043 non-null   int64
#  8   married               7043 non-null   object
# dtypes: int64(2), object(7)
# memory usage: 495.3+ KB

# %%
for i in customer_info.columns:
    print(customer_info[i].value_counts(dropna=False))
    print(customer_info[i].unique())
    print('\n')
# Out:
# customer_id
# 9995-HOTOH    1
# 0002-ORFBO    1
# 0003-MKNFE    1
# 9970-QBCDA    1
# 9968-FFVVH    1
#              ..
# 0014-BMAQU    1
# 0013-SMEOE    1
# 0013-MHZWF    1
# 0013-EXCHZ    1
# 0011-IGKFF    1
# Name: count, Length: 7043, dtype: int64
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
#
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64
# ['Female' 'Male']
#
#
# age
# 42    156
# 47    153
# 40    150
# 44    148
# 23    146
#      ...
# 80     66
# 78     63
# 66     63
# 67     61
# 72     58
# Name: count, Length: 62, dtype: int64
# [37 46 50 78 75 23 67 52 68 43 47 25 58 32 39 72 79 26 30 22 34 42 64 48
#  28 33 31 60 69 20 57 19 38 54 35 51 66 61 24 55 59 71 49 40 21 45 29 62
#  76 77 73 41 56 80 63 53 44 70 74 36 27 65]
#
#
# under_30
# No     5642
# Yes    1401
# Name: count, dtype: int64
# ['No' 'Yes']
#
#
# senior_citizen
# No     5901
# Yes    1142
# Name: count, dtype: int64
# ['No' 'Yes']
#
#
# ...

# %%
customer_info[customer_info.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, gender, age, under_30, senior_citizen, partner, dependents, number_of_dependents, married]
# Index: []

# %%
customer_info.drop(columns=['partner','dependents'],inplace=True)

# %% [markdown]
# # LOCATION_DATA.CSV (Data is clean,no null values,no duplicates)

# %%
location.head()
# Out:
#   customer_id        country       state          city  zip_code  \
# 0  0002-ORFBO  United States  California  Frazier Park     93225
# 1  0003-MKNFE  United States  California      Glendale     91206
# 2  0004-TLHLJ  United States  California    Costa Mesa     92627
# 3  0011-IGKFF  United States  California      Martinez     94553
# 4  0013-EXCHZ  United States  California     Camarillo     93010
#
#    total_population   latitude   longitude
# 0              4498  34.827662 -118.999073
# 1             31297  34.162515 -118.203869
# 2             62069  33.645672 -117.922613
# 3             46677  38.014457 -122.115432
# 4             42853  34.227846 -119.079903

# %%
location.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customer_id       7043 non-null   object
#  1   country           7043 non-null   object
#  2   state             7043 non-null   object
#  3   city              7043 non-null   object
#  4   zip_code          7043 non-null   int64
#  5   total_population  7043 non-null   int64
#  6   latitude          7043 non-null   float64
#  7   longitude         7043 non-null   float64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 440.3+ KB

# %%
for i in location.columns:
    print(location[i].value_counts(dropna=False))
    print(location[i].unique())
    print("\n")
# Out:
# customer_id
# 9995-HOTOH    1
# 0002-ORFBO    1
# 0003-MKNFE    1
# 9970-QBCDA    1
# 9968-FFVVH    1
#              ..
# 0014-BMAQU    1
# 0013-SMEOE    1
# 0013-MHZWF    1
# 0013-EXCHZ    1
# 0011-IGKFF    1
# Name: count, Length: 7043, dtype: int64
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
#
# country
# United States    7043
# Name: count, dtype: int64
# ['United States']
#
#
# state
# California    7043
# Name: count, dtype: int64
# ['California']
#
#
# city
# Los Angeles         293
# San Diego           285
# San Jose            112
# Sacramento          108
# San Francisco       104
#                    ...
# Eldridge              2
# Holtville             2
# Johannesburg          2
# South Lake Tahoe      2
# Jacumba               2
# Name: count, Length: 1106, dtype: int64
# ['Frazier Park' 'Glendale' 'Costa Mesa' ... 'Jacumba' 'Carpinteria'
#  'Meadow Valley']
#
#
# zip_code
# 92028    43
# 92027    38
# 92122    36
# ...

# %%
for i in location['city']:
    print(i)
# Out:
# Frazier Park
# Glendale
# Costa Mesa
# Martinez
# Camarillo
# Midpines
# Lompoc
# Napa
# Simi Valley
# Sheridan
# Rancho Santa Fe
# Sunnyvale
# Antelope
# La Mesa
# Los Olivos
# Woodlake
# Point Reyes Station
# San Marcos
# Daly City
# Morgan Hill
# Ahwahnee
# Carnelian Bay
# Alpaugh
# Keeler
# Korbel
# Palomar Mountain
# Parlier
# Modesto
# Glen Ellen
# Eureka
# Moss Beach
# Los Angeles
# Los Angeles
# Calexico
# Redding
# San Martin
# Stockton
# Los Angeles
# Huntington Park
# Yermo
# San Diego
# Fremont
# Santa Rosa
# San Jose
# Tujunga
# Visalia
# Lodi
# El Portal
# Calistoga
# Farmington
# Tulelake
# Coleville
# Ojai
# Desert Hot Springs
# North Hollywood
# Inverness
# Santa Rosa
# San Jose
# Wilmington
# Modesto
# San Diego
# Rancho Palos Verdes
# Kenwood
# West Point
# Los Angeles
# Morongo Valley
# Palo Verde
# Valyermo
# Cambria
# Round Mountain
# Klamath
# Fresno
# Angwin
# Le Grand
# Redway
# San Diego
# Monterey Park
# Big Oak Flat
# Stevenson Ranch
# North Highlands
# ...

# %%
location[location.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, country, state, city, zip_code, total_population, latitude, longitude]
# Index: []

# %%
location.drop(columns=['state','country','latitude','longitude'],inplace=True)

# %% [markdown]
# # ONLINE_SERVICES.CSV (Data has null values and no duplicates)

# %%
services.head()
# Out:
#   customer_id phone_service internet_service online_security online_backup  \
# 0  0002-ORFBO           Yes              Yes              No           Yes
# 1  0003-MKNFE           Yes              Yes              No            No
# 2  0004-TLHLJ           Yes              Yes              No            No
# 3  0011-IGKFF           Yes              Yes              No           Yes
# 4  0013-EXCHZ           Yes              Yes              No            No
#
#   device_protection premium_tech_support streaming_tv streaming_movies  \
# 0                No                  Yes          Yes               No
# 1                No                   No           No              Yes
# 2               Yes                   No           No               No
# 3               Yes                   No          Yes              Yes
# 4                No                  Yes          Yes               No
#
#   streaming_music internet_type
# 0              No         Cable
# ...

# %%
services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   customer_id           7043 non-null   object
#  1   phone_service         7043 non-null   object
#  2   internet_service      7043 non-null   object
#  3   online_security       7043 non-null   object
#  4   online_backup         7043 non-null   object
#  5   device_protection     7043 non-null   object
#  6   premium_tech_support  7043 non-null   object
#  7   streaming_tv          7043 non-null   object
#  8   streaming_movies      7043 non-null   object
#  9   streaming_music       7043 non-null   object
#  10  internet_type         5517 non-null   object
# dtypes: object(11)
# memory usage: 605.4+ KB

# %%
for i in services.columns:
    print(services[i].value_counts(dropna=False))
    print(services[i].unique())
    print('\n')
# Out:
# customer_id
# 9995-HOTOH    1
# 0002-ORFBO    1
# 0003-MKNFE    1
# 9970-QBCDA    1
# 9968-FFVVH    1
#              ..
# 0014-BMAQU    1
# 0013-SMEOE    1
# 0013-MHZWF    1
# 0013-EXCHZ    1
# 0011-IGKFF    1
# Name: count, Length: 7043, dtype: int64
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
#
# phone_service
# Yes    6361
# No      682
# Name: count, dtype: int64
# ['Yes' 'No']
#
#
# internet_service
# Yes    5517
# No     1526
# Name: count, dtype: int64
# ['Yes' 'No']
#
#
# online_security
# No     5024
# Yes    2019
# Name: count, dtype: int64
# ['No' 'Yes']
#
#
# online_backup
# No     4614
# Yes    2429
# Name: count, dtype: int64
# ['Yes' 'No']
#
#
# device_protection
# No     4621
# Yes    2422
# Name: count, dtype: int64
# ['No' 'Yes']
#
#
# premium_tech_support
# No     4999
# Yes    2044
# Name: count, dtype: int64
# ['Yes' 'No']
#
#
# streaming_tv
# No     4336
# Yes    2707
# Name: count, dtype: int64
# ['Yes' 'No']
#
#
# ...

# %%
services['internet_service']=services['internet_service'].fillna('No')

# %%
services[services.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, phone_service, internet_service, online_security, online_backup, device_protection, premium_tech_support, streaming_tv, streaming_movies, streaming_music, internet_type]
# Index: []

# %% [markdown]
# # PAYMENT_INFO.CSV (Data is clean,no null values,no duplicates)

# %%
payment_info.head()
# Out:
#   customer_id        contract paperless_billing    payment_method  \
# 0  0002-ORFBO        One Year               Yes      Mailed check
# 1  0003-MKNFE  Month-to-Month                No      Mailed check
# 2  0004-TLHLJ  Month-to-Month               Yes  Electronic check
# 3  0011-IGKFF  Month-to-Month               Yes  Electronic check
# 4  0013-EXCHZ  Month-to-Month               Yes      Mailed check
#
#    monthly_ charges  avg_monthly_long_distance_charges  total_charges  \
# 0              65.6                              42.39         593.30
# 1              59.9                              10.69         542.40
# 2              73.9                              33.65         280.85
# 3              98.0                              27.82        1237.85
# 4              83.9                               7.38         267.40
#
#    total_refunds  total_extra_data_charges  total_long_distance_charges  \
# ...

# %%
payment_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 11 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   customer_id                        7043 non-null   object
#  1   contract                           7043 non-null   object
#  2   paperless_billing                  7043 non-null   object
#  3   payment_method                     7043 non-null   object
#  4   monthly_ charges                   7043 non-null   float64
#  5   avg_monthly_long_distance_charges  7043 non-null   float64
#  6   total_charges                      7043 non-null   float64
#  7   total_refunds                      7043 non-null   float64
#  8   total_extra_data_charges           7043 non-null   int64
#  9   total_long_distance_charges        7043 non-null   float64
#  10  total_revenue                      7043 non-null   float64
# ...

# %%
for i in payment_info.columns:
    print(payment_info[i].value_counts(dropna=False))
    print(payment_info[i].unique())
    print('\n')
# Out:
# customer_id
# 9995-HOTOH    1
# 0002-ORFBO    1
# 0003-MKNFE    1
# 9970-QBCDA    1
# 9968-FFVVH    1
#              ..
# 0014-BMAQU    1
# 0013-SMEOE    1
# 0013-MHZWF    1
# 0013-EXCHZ    1
# 0011-IGKFF    1
# Name: count, Length: 7043, dtype: int64
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
#
# contract
# Month-to-Month    3610
# Two Year          1883
# One Year          1550
# Name: count, dtype: int64
# ['One Year' 'Month-to-Month' 'Two Year']
#
#
# paperless_billing
# Yes    4171
# No     2872
# Name: count, dtype: int64
# ['Yes' 'No']
#
#
# payment_method
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64
# ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
#
#
# monthly_ charges
# 20.05     61
# 19.85     45
# 19.95     44
# 19.90     44
# 19.70     43
#           ..
# ...

# %%
payment_info[payment_info.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, contract, paperless_billing, payment_method, monthly_ charges, avg_monthly_long_distance_charges, total_charges, total_refunds, total_extra_data_charges, total_long_distance_charges, total_revenue]
# Index: []

# %% [markdown]
# # SERVICES_OPTIONS.CSV (Data has null values and no duplicates)

# %%
service_options.head()
# Out:
#   customer_id  tenure internet_service phone_service multiple_lines  \
# 0  0002-ORFBO       9              Yes           Yes             No
# 1  0003-MKNFE       9              Yes           Yes            Yes
# 2  0004-TLHLJ       4              Yes           Yes             No
# 3  0011-IGKFF      13              Yes           Yes             No
# 4  0013-EXCHZ       3              Yes           Yes             No
#
#    avg_monthly_gb_download unlimited_data    offer referred_a_friend  \
# 0                       16            Yes      NaN               Yes
# 1                       10             No      NaN                No
# 2                       30            Yes  Offer E                No
# 3                        4            Yes  Offer D               Yes
# 4                       11            Yes      NaN               Yes
#
#    number_of_referrals
# 0                    2
# 1                    0
# 2                    0
# 3                    1
# ...

# %%
service_options.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   customer_id              7043 non-null   object
#  1   tenure                   7043 non-null   int64
#  2   internet_service         7043 non-null   object
#  3   phone_service            7043 non-null   object
#  4   multiple_lines           7043 non-null   object
#  5   avg_monthly_gb_download  7043 non-null   int64
#  6   unlimited_data           7043 non-null   object
#  7   offer                    3166 non-null   object
#  8   referred_a_friend        7043 non-null   object
#  9   number_of_referrals      7043 non-null   int64
# dtypes: int64(3), object(7)
# memory usage: 550.4+ KB

# %%
for i in service_options.columns:
    print(service_options[i].value_counts(dropna=False))
    print(service_options[i].unique())
    print('\n')
# Out:
# customer_id
# 9995-HOTOH    1
# 0002-ORFBO    1
# 0003-MKNFE    1
# 9970-QBCDA    1
# 9968-FFVVH    1
#              ..
# 0014-BMAQU    1
# 0013-SMEOE    1
# 0013-MHZWF    1
# 0013-EXCHZ    1
# 0011-IGKFF    1
# Name: count, Length: 7043, dtype: int64
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
#
# tenure
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 28     57
# 39     56
# 44     51
# 36     50
# 0      11
# Name: count, Length: 73, dtype: int64
# [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 37 49 66 67
#  20 43 59 12 27  2 25 29 14 35 64 39 40 11  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 31 36 17 18 51 38 42
#   0]
#
#
# internet_service
# Yes    5517
# No     1526
# Name: count, dtype: int64
# ['Yes' 'No']
#
#
# phone_service
# Yes    6361
# No      682
# Name: count, dtype: int64
# ['Yes' 'No']
#
#
# multiple_lines
# No     4072
# Yes    2971
# ...

# %%
service_options['offer']=service_options['offer'].fillna('No')

# %%
service_options[service_options.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, tenure, internet_service, phone_service, multiple_lines, avg_monthly_gb_download, unlimited_data, offer, referred_a_friend, number_of_referrals]
# Index: []

# %% [markdown]
# # STATUS_ANALYSIS.CSV (Data has null values and no duplicates)

# %%
status.head()
# Out:
#   customer_id  satisfaction_score  cltv customer_status  churn_score  \
# 0  0002-ORFBO                   3  2205          Stayed           65
# 1  0003-MKNFE                   5  5414          Stayed           66
# 2  0004-TLHLJ                   1  4479         Churned           71
# 3  0011-IGKFF                   1  3714         Churned           91
# 4  0013-EXCHZ                   1  3464         Churned           68
#
#   churn_label  churn_value   churn_category                   churn_reason
# 0          No            0   Not Applicable                            NaN
# 1          No            0   Not Applicable                            NaN
# 2         Yes            1       Competitor  Competitor had better devices
# 3         Yes            1  Dissatisfaction        Product dissatisfaction
# 4         Yes            1  Dissatisfaction            Network reliability

# %%
status.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         7043 non-null   object
#  1   satisfaction_score  7043 non-null   int64
#  2   cltv                7043 non-null   int64
#  3   customer_status     7043 non-null   object
#  4   churn_score         7043 non-null   int64
#  5   churn_label         7043 non-null   object
#  6   churn_value         7043 non-null   int64
#  7   churn_category      7043 non-null   object
#  8   churn_reason        1869 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 495.3+ KB

# %%
for i in status.columns:
    print(status[i].value_counts(dropna=False))
    print(status[i].unique())
    print('\n')
# Out:
# customer_id
# 9995-HOTOH    1
# 0002-ORFBO    1
# 0003-MKNFE    1
# 9970-QBCDA    1
# 9968-FFVVH    1
#              ..
# 0014-BMAQU    1
# 0013-SMEOE    1
# 0013-MHZWF    1
# 0013-EXCHZ    1
# 0011-IGKFF    1
# Name: count, Length: 7043, dtype: int64
# ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
#
#
# satisfaction_score
# 3    2665
# 4    1789
# 5    1149
# 1     922
# 2     518
# Name: count, dtype: int64
# [3 5 1 4 2]
#
#
# cltv
# 5546    8
# 5137    7
# 5527    7
# 5461    7
# 4741    7
#        ..
# 5555    1
# 3613    1
# 4791    1
# 2365    1
# 2139    1
# Name: count, Length: 3438, dtype: int64
# [2205 5414 4479 ... 3245 5773 5639]
#
#
# customer_status
# Stayed     4720
# Churned    1869
# Joined      454
# Name: count, dtype: int64
# ['Stayed' 'Churned' 'Joined']
#
#
# churn_score
# 91    202
# 80    150
# 71    148
# 77    145
# 67    142
#      ...
# 88     33
# 9       3
# 8       2
# 7       2
# 5       1
# ...

# %%
status['churn_reason']=status['churn_reason'].fillna('''Don't know''')

# %%
status[status.duplicated()]
# Out:
# Empty DataFrame
# Columns: [customer_id, satisfaction_score, cltv, customer_status, churn_score, churn_label, churn_value, churn_category, churn_reason]
# Index: []

# %% [markdown]
# # REMOVING Customer_ID column

# %%
dfs=[status,service_options,payment_info,customer_info,location,services]
for i in dfs:
    i.drop(columns=['customer_id'],inplace=True)

# %% [markdown]
# # CREATING NEW DATASET

# %%
target=status['customer_status']

# %%
new_df=pd.concat([customer_info,location,services,payment_info,service_options,target,status[['churn_reason','churn_value']]],axis=1)

# %%
new_df
# Out:
#       gender  age under_30 senior_citizen  number_of_dependents married  \
# 0     Female   37       No             No                     0     Yes
# 1       Male   46       No             No                     0      No
# 2       Male   50       No             No                     0      No
# 3       Male   78       No            Yes                     0     Yes
# 4     Female   75       No            Yes                     0     Yes
# ...      ...  ...      ...            ...                   ...     ...
# 7038  Female   20      Yes             No                     0      No
# 7039    Male   40       No             No                     0     Yes
# 7040    Male   22      Yes             No                     0      No
# 7041    Male   21      Yes             No                     0     Yes
# 7042    Male   36       No             No                     0     Yes
#
#               city  zip_code  total_population phone_service  ...  \
# ...

# %%
new_df.to_csv('../Dataset/combined_data.csv',index=False)
